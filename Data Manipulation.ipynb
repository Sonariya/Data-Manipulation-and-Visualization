# %%
import numpy as np
import pandas as pd

# %%
## reading the data from github
data=pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv', sep='\t')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# checking the head
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
## checking the end part
data.tail()
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 151          152         1       1  Pears, Mrs. Thomas (Edith Wearne)  female
# 152          153         0       3                   Meo, Mr. Alfonzo    male
# 153          154         0       3    van Billiard, Mr. Austin Blyler    male
# 154          155         0       3              Olsen, Mr. Ole Martin    male
# 155          156         0       1        Williams, Mr. Charles Duane    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 151  22.0      1      0      113776  66.6000    C2        S
# 152  55.5      0      0  A.5. 11206   8.0500   NaN        S
# 153  40.5      0      2    A/5. 851  14.5000   NaN        S
# 154   NaN      0      0   Fa 265302   7.3125   NaN        S
# 155  51.0      0      1    PC 17597  61.3792   NaN        C

# %%
## Describe the statistics of numerical data
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
data.describe(include='O') ## unique represents how many unique lebels are presents in feature
# Out:
#                      Name   Sex  Ticket        Cabin Embarked
# count                 156   156     156           31      155
# unique                156     2     145           28        3
# top     Rugg, Miss. Emily  male  237736  C23 C25 C27        S
# freq                    1   100       2            2      110

# %%
data.describe(include='O')
# Out:
#                      Name   Sex  Ticket        Cabin Embarked
# count                 156   156     156           31      155
# unique                156     2     145           28        3
# top     Rugg, Miss. Emily  male  237736  C23 C25 C27        S
# freq                    1   100       2            2      110

# %%
## Getting the columns name
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# information about datatype
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          126 non-null    float64
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        31 non-null     object
#  11  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %%
# unique and categorical and discrete
data.Sex.unique() ## give the unique label
# Out:
# array(['male', 'female'], dtype=object)

# %%
data.Name.unique()
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Williams, Mr. Charles Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Masselmani, Mrs. Fatima', 'Fynney, Mr. Joseph J',
#        'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"',
# ...

# %%
data.Survived.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
## value count
data.Sex.value_counts()
# Out:
# male      100
# female     56
# Name: Sex, dtype: int64

# %%
data.Pclass.value_counts()
# Out:
# 3    96
# 2    30
# 1    30
# Name: Pclass, dtype: int64

# %%
data.Cabin.value_counts(dropna=False)
# Out:
# NaN            125
# C23 C25 C27      2
# C123             2
# D26              2
# E46              1
# E101             1
# A6               1
# B58 B60          1
# F2               1
# C83              1
# B86              1
# A5               1
# C103             1
# F E69            1
# B28              1
# E31              1
# F33              1
# G6               1
# C110             1
# C85              1
# B30              1
# C52              1
# D33              1
# D10 D12          1
# F G73            1
# C2               1
# D56              1
# D47              1
# B78              1
# Name: Cabin, dtype: int64

# %%
type(data.Cabin.value_counts(dropna=False))
# Out:
# pandas.core.series.Series

# %%
## getting the specific column from dataframe
data['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 151    1
# 152    0
# 153    0
# 154    0
# 155    0
# Name: Survived, Length: 156, dtype: int64

# %%
pd.set_option('display.max_rows',None) # displaying all rows

# %%
pd.reset_option('display.max_rows',None)

# %%
pd.set_option('display.max_columns',None) # displaying all columns

# %%
 ## getting multiple
data[['Survived','Age','Sex']]
# Out:
#      Survived   Age     Sex
# 0           0  22.0    male
# 1           1  38.0  female
# 2           1  26.0  female
# 3           1  35.0  female
# 4           0  35.0    male
# ..        ...   ...     ...
# 151         1  22.0  female
# 152         0  55.5    male
# 153         0  40.5    male
# 154         0   NaN    male
# 155         0  51.0    male
#
# [156 rows x 3 columns]

# %%
# Want new dataframe which will have columns from data
d1=data[['Survived','Age','Sex']]
d1
# Out:
#      Survived    Age     Sex
# 0           0  22.00    male
# 1           1  38.00  female
# 2           1  26.00  female
# 3           1  35.00  female
# 4           0  35.00    male
# 5           0    NaN    male
# 6           0  54.00    male
# 7           0   2.00    male
# 8           1  27.00  female
# 9           1  14.00  female
# 10          1   4.00  female
# 11          1  58.00  female
# 12          0  20.00    male
# 13          0  39.00    male
# 14          0  14.00  female
# 15          1  55.00  female
# 16          0   2.00    male
# 17          1    NaN    male
# 18          0  31.00  female
# 19          1    NaN  female
# 20          0  35.00    male
# 21          1  34.00    male
# 22          1  15.00  female
# 23          1  28.00    male
# 24          0   8.00  female
# 25          1  38.00  female
# 26          0    NaN    male
# 27          0  19.00    male
# 28          1    NaN  female
# 29          0    NaN    male
# 30          0  40.00    male
# ...

# %%
## getting specific row from specific column
d1['Survived'][15:30]
# Out:
# 15    1
# 16    0
# 17    1
# 18    0
# 19    1
# 20    0
# 21    1
# 22    1
# 23    1
# 24    0
# 25    1
# 26    0
# 27    0
# 28    1
# 29    0
# Name: Survived, dtype: int64

# %%
data.iloc[0:15,[1,6,8]]
# Out:
#     Survived  SibSp            Ticket
# 0          0      1         A/5 21171
# 1          1      1          PC 17599
# 2          1      0  STON/O2. 3101282
# 3          1      1            113803
# 4          0      0            373450
# 5          0      0            330877
# 6          0      0             17463
# 7          0      3            349909
# 8          1      0            347742
# 9          1      1            237736
# 10         1      1           PP 9549
# 11         1      0            113783
# 12         0      0         A/5. 2151
# 13         0      1            347082
# 14         0      0            350406

# %%
data.iloc[100:125,[3,5,7]]
# Out:
#                                   Name   Age  Parch
# 100            Petranec, Miss. Matilda  28.0      0
# 101   Petroff, Mr. Pastcho ("Pentcho")   NaN      0
# 102          White, Mr. Richard Frasar  21.0      1
# 103         Johansson, Mr. Gustaf Joel  33.0      0
# 104     Gustafsson, Mr. Anders Vilhelm  37.0      0
# 105              Mionoff, Mr. Stoytcho  28.0      0
# 106   Salkjelsvik, Miss. Anna Kristine  21.0      0
# 107             Moss, Mr. Albert Johan   NaN      0
# 108                    Rekic, Mr. Tido  38.0      0
# 109                Moran, Miss. Bertha   NaN      0
# 110     Porter, Mr. Walter Chamberlain  47.0      0
# 111               Zabour, Miss. Hileni  14.5      0
# 112             Barton, Mr. David John  22.0      0
# 113            Jussila, Miss. Katriina  20.0      0
# 114              Attalah, Miss. Malake  17.0      0
# 115              Pekoniemi, Mr. Edvard  21.0      0
# 116               Connors, Mr. Patrick  70.5      0
# ...

# %%
data.iloc[1:50:5,1:8] # using step
# step func not requried here basically that will not helpful to data analize
# Out:
#     Survived  Pclass                                               Name  \
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6          0       1                            McCarthy, Mr. Timothy J
# 11         1       1                           Bonnell, Miss. Elizabeth
# 16         0       3                               Rice, Master. Eugene
# 21         1       2                              Beesley, Mr. Lawrence
# 26         0       3                            Emir, Mr. Farred Chehab
# 31         1       1     Spencer, Mrs. William Augustus (Marie Eugenie)
# 36         1       3                                   Mamee, Mr. Hanna
# 41         0       2  Turpin, Mrs. William John Robert (Dorothy Ann ...
# 46         0       3                                  Lennon, Mr. Denis
#
#        Sex   Age  SibSp  Parch
# 1   female  38.0      1      0
# 6     male  54.0      0      0
# 11  female  58.0      0      0
# 16    male   2.0      4      1
# ...

# %%
data.loc[data['Sex']=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...

# %%
data.loc[data['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 24            25         0       3
# 26            27         0       3
# 27            28         0       1
# 29            30         0       3
# 30            31         0       1
# 33            34         0       2
# 34            35         0       1
# 35            36         0       1
# 37            38         0       3
# 38            39         0       3
# 40            41         0       3
# 41            42         0       2
# 42            43         0       3
# 45            46         0       3
# ...

# %%
data.loc[(data['Sex']=='male') & (data['Age']<1)]
# Out:
#     PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 78           79         1       2  Caldwell, Master. Alden Gates  male  0.83
#
#     SibSp  Parch  Ticket  Fare Cabin Embarked
# 78      0      2  248738  29.0   NaN        S

# %%
data.loc[(data['Sex']=='female') & (data['Age']<38)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# 18            19         0       3
# 22            23         1       3
# 24            25         0       3
# 38            39         0       3
# 39            40         1       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 49            50         0       3
# 53            54         1       2
# 56            57         1       2
# 58            59         1       2
# 66            67         1       2
# 68            69         1       3
# 71            72         0       3
# 79            80         1       3
# 84            85         1       2
# 85            86         1       3
# 88            89         1       1
# ...

# %%
data.loc[(data['Sex']=='female') | (data['Age']<38) & (data['Fare']<50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# ...

# %%
## when  you want to set any specific column as index
data.set_index('Sex') # inplace=True will make changes in your original dataframe 
## inplace=False will not make any changes in dataframe
# Out:
#         PassengerId  Survived  Pclass  \
# Sex
# male              1         0       3
# female            2         1       1
# female            3         1       3
# female            4         1       1
# male              5         0       3
# male              6         0       3
# male              7         0       1
# male              8         0       3
# female            9         1       3
# female           10         1       2
# female           11         1       3
# female           12         1       1
# male             13         0       3
# male             14         0       3
# female           15         0       3
# female           16         1       2
# male             17         0       3
# male             18         1       2
# female           19         0       3
# female           20         1       3
# male             21         0       2
# male             22         1       2
# female           23         1       3
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.reset_index()
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# 5        5            6         0       3
# 6        6            7         0       1
# 7        7            8         0       3
# 8        8            9         1       3
# 9        9           10         1       2
# 10      10           11         1       3
# 11      11           12         1       1
# 12      12           13         0       3
# 13      13           14         0       3
# 14      14           15         0       3
# 15      15           16         1       2
# 16      16           17         0       3
# 17      17           18         1       2
# 18      18           19         0       3
# 19      19           20         1       3
# 20      20           21         0       2
# ...

# %%
## creating new column in original dataframe
data['DS']='Data Science'
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked            DS
# 0      0         A/5 21171   7.2500   NaN        S  Data Science
# 1      0          PC 17599  71.2833   C85        C  Data Science
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Data Science
# ...

# %%
## Dropping the column
data.drop('DS',axis=1,inplace=True) #axis=0 refers to row and axis=1 refers to column

# %%
## Droping the row
data.drop(1,axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# ...

# %%
## Droping multiple row
data.drop([1,3,5,67,87],axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# ...

# %%
# copy
new_data=data.copy()
new_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
## Creating new column using existing column
data['Family']=data['SibSp']+data['Parch']
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Family
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       1
# ...

# %% [markdown]
# # Missing Values

# %%
##Counting the missing values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             30
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64

# %%
## getting the indexes of rows where values are missing in specific column
missing=np.where(data['Age'].isnull()==True)

# %%
missing
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
##getting the actual data using indexes
data.iloc[missing]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
## handling the missing values
## 1> Imputation   2>Dropping

# %%
## FillNa
data.fillna(value='MISSING' )
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex      Age  \
# 0                              Braund, Mr. Owen Harris    male       22
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       38
# 2                               Heikkinen, Miss. Laina  female       26
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       35
# 4                             Allen, Mr. William Henry    male       35
# ..                                                 ...     ...      ...
# ...

# %%
data.fillna(value=data['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
data.fillna(method='bfill')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## Using a loc function to impute missing on a specific column
data.loc[data['Age'].isnull()==True,'Age']=data['Age'].mean()

# %%
data['Age'].isnull().sum()
# Out:
# 0

# %%
data['Age'][100:120]
# Out:
# 100    28.000000
# 101    28.141508
# 102    21.000000
# 103    33.000000
# 104    37.000000
# 105    28.000000
# 106    21.000000
# 107    28.141508
# 108    38.000000
# 109    28.141508
# 110    47.000000
# 111    14.500000
# 112    22.000000
# 113    20.000000
# 114    17.000000
# 115    21.000000
# 116    70.500000
# 117    29.000000
# 118    24.000000
# 119     2.000000
# Name: Age, dtype: float64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
https://pandas.pydata.org/pandas-docs/stable/reference/io.html

# %% [markdown]
# ## Sorting the DataFrame

# %%
## Sorting
data.sort_values('Age', ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# 33            34         0       2                     Wheadon, Mr. Edward H
# 54            55         0       1            Ostby, Mr. Engelhart Cornelius
# 94            95         0       3                         Coxon, Mr. Daniel
# ..           ...       ...     ...                                       ...
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 16            17         0       3                      Rice, Master. Eugene
# 119          120         0       3         Andersson, Miss. Ellis Anna Maria
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 78            79         1       2             Caldwell, Master. Alden Gates
#
# ...

# %%
data.sort_values('Sex')
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 47            48         1       3           O'Driscoll, Miss. Bridget
# 106          107         1       3    Salkjelsvik, Miss. Anna Kristine
# 136          137         1       1        Newsom, Miss. Helen Monypeny
# 38            39         0       3  Vander Planke, Miss. Augusta Maria
# 39            40         1       3         Nicola-Yarred, Miss. Jamila
# ..           ...       ...     ...                                 ...
# 63            64         0       3               Skoog, Master. Harald
# 62            63         0       1         Harris, Mr. Henry Birkhardt
# 60            61         0       3               Sirayanian, Mr. Orsen
# 76            77         0       3                   Staneff, Mr. Ivan
# 155          156         0       1         Williams, Mr. Charles Duane
#
#         Sex        Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %%
data.sort_values(by=['Age','Pclass'])
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 78            79         1       2             Caldwell, Master. Alden Gates
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 16            17         0       3                      Rice, Master. Eugene
# 119          120         0       3         Andersson, Miss. Ellis Anna Maria
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 94            95         0       3                         Coxon, Mr. Daniel
# 54            55         0       1            Ostby, Mr. Engelhart Cornelius
# 33            34         0       2                     Wheadon, Mr. Edward H
# 116          117         0       3                      Connors, Mr. Patrick
# 96            97         0       1                 Goldschmidt, Mr. George B
#
# ...

# %%
data.sort_values(by=['Name','Fare'])
# Out:
#      PassengerId  Survived  Pclass  \
# 40            41         0       3
# 4              5         0       3
# 119          120         0       3
# 68            69         1       3
# 13            14         0       3
# ..           ...       ...     ...
# 155          156         0       1
# 17            18         1       2
# 55            56         1       1
# 111          112         0       3
# 153          154         0       3
#
#                                                Name     Sex        Age  SibSp  \
# 40   Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.000000      1
# 4                          Allen, Mr. William Henry    male  35.000000      0
# 119               Andersson, Miss. Ellis Anna Maria  female   2.000000      4
# 68                  Andersson, Miss. Erna Alexandra  female  17.000000      4
# 13                      Andersson, Mr. Anders Johan    male  39.000000      1
# ...

# %% [markdown]
# ## Grouping the data

# %%
data.groupby(data['Sex']).sum()
# Out:
#         PassengerId  Survived  Pclass          Age  SibSp  Parch       Fare
# Sex
# female         3815        40     138  1403.273571     49     29  1593.7958
# male           8431        14     240  2986.801667     47     33  2791.2998

# %%
data.groupby([data['Sex']]).count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female           56        56      56    56   47     56     56      56    56
# male            100       100     100   100   79    100    100     100   100
#
#         Cabin  Embarked
# Sex
# female     13        55
# male       18       100

# %%
data.groupby(data['Age']).mean()
# Out:
#            PassengerId  Survived    Pclass     SibSp     Parch        Fare
# Age
# 0.830000     79.000000  1.000000  2.000000  0.000000  2.000000   29.000000
# 2.000000     48.333333  0.000000  3.000000  3.666667  1.333333   27.158333
# 3.000000     44.000000  1.000000  2.000000  1.000000  2.000000   41.579200
# 4.000000     37.500000  0.500000  3.000000  2.000000  1.500000   22.300000
# 5.000000     59.000000  1.000000  2.000000  1.000000  2.000000   27.750000
# 7.000000     51.000000  0.000000  3.000000  4.000000  1.000000   39.687500
# 8.000000     25.000000  0.000000  3.000000  3.000000  1.000000   21.075000
# 9.000000    148.000000  0.000000  3.000000  2.000000  2.000000   34.375000
# 11.000000    60.000000  0.000000  3.000000  5.000000  2.000000   46.900000
# 12.000000   126.000000  1.000000  3.000000  1.000000  0.000000   11.241700
# 14.000000    21.666667  0.666667  2.666667  0.666667  0.000000   16.388900
# ...

# %%
data.groupby(data['Sex']).aggregate({'Fare':'max'})
# Out:
#          Fare
# Sex
# female  263.0
# male    263.0

# %%
data.groupby(data['Age']).min(30)
# Out:
#            PassengerId  Survived  Pclass  SibSp  Parch     Fare
# Age
# 0.830000            79         1       2      0      2  29.0000
# 2.000000             8         0       3      3      1  21.0750
# 3.000000            44         1       2      1      2  41.5792
# 4.000000            11         0       3      1      1  16.7000
# 5.000000            59         1       2      1      2  27.7500
# 7.000000            51         0       3      4      1  39.6875
# 8.000000            25         0       3      3      1  21.0750
# 9.000000           148         0       3      2      2  34.3750
# 11.000000           60         0       3      5      2  46.9000
# 12.000000          126         1       3      1      0  11.2417
# 14.000000           10         0       2      0      0   7.8542
# 14.500000          112         0       3      1      0  14.4542
# 15.000000           23         1       3      0      0   8.0292
# 16.000000           72         0       3      0      0   9.2167
# ...

# %% [markdown]
# ## How to Change Datatype

# %%
data['Age']=data.Age.astype('float16')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          156 non-null    float16
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        31 non-null     object
#  11  Embarked     155 non-null    object
# dtypes: float16(1), float64(1), int64(5), object(5)
# memory usage: 13.8+ KB

# %%
data['Fare']=data.Fare.astype('float16')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int16
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          156 non-null    float16
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float16
#  10  Cabin        31 non-null     object
#  11  Embarked     155 non-null    object
# dtypes: float16(2), int16(1), int64(4), object(5)
# memory usage: 12.0+ KB

# %%
data['PassengerId']=data.PassengerId.astype('int16')

# %%
pd.to_numeric(data.Parch,downcast='integer')
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 151    0
# 152    0
# 153    2
# 154    0
# 155    1
# Name: Parch, Length: 156, dtype: int8

# %% [markdown]
# ## Joining the DataFrame

# %%
df1=pd.DataFrame({'A':['A0','A1','A2','A3','A4','A5'],
                 'B':['B0','B1','B2','B3','B4','B5'],
                'C':['C0','C1','C2','C3','C4','C5'],
                'D':['D0','D1','D2','D3','D4','D5']})

# %%
df2=pd.DataFrame({'A':['A0','A1','A2','A3','A4','A5'],
                 'B':['B0','B1','B2','B3','B4','B5'],
                'C':['C0','C1','C2','C3','C4','C5'],
                'D':['D0','D1','D2','D3','D4','D5']})

# %%
##when 2 dataframe have same columns and we need to just append the row

pd.concat([df1,df2],axis=0,ignore_index=True)
# Out:
#      A   B   C   D
# 0   A0  B0  C0  D0
# 1   A1  B1  C1  D1
# 2   A2  B2  C2  D2
# 3   A3  B3  C3  D3
# 4   A4  B4  C4  D4
# 5   A5  B5  C5  D5
# 6   A0  B0  C0  D0
# 7   A1  B1  C1  D1
# 8   A2  B2  C2  D2
# 9   A3  B3  C3  D3
# 10  A4  B4  C4  D4
# 11  A5  B5  C5  D5

# %%
##when 2 dataframe have same columns and we need to just append according to the column
pd.concat([df1,df2],axis=1)
# Out:
#     A   B   C   D   A   B   C   D
# 0  A0  B0  C0  D0  A0  B0  C0  D0
# 1  A1  B1  C1  D1  A1  B1  C1  D1
# 2  A2  B2  C2  D2  A2  B2  C2  D2
# 3  A3  B3  C3  D3  A3  B3  C3  D3
# 4  A4  B4  C4  D4  A4  B4  C4  D4
# 5  A5  B5  C5  D5  A5  B5  C5  D5
